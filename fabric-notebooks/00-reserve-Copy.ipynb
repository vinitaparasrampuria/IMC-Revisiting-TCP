# %% [markdown]
# # Reserve and configure FABRIC resources for reproducing "Revisiting TCP Congestion Control Throughput Models & Fairness Properties at Scale"

# %% [markdown]
# ## Set up your FABRIC environment
#
# This assumes that you have already configured your FABRIC account and your Jupyter environment as described in [Hello, FABRIC](https://teaching-on-testbeds.github.io/blog/hello-fabric).

# %%
from fabrictestbed_extensions.fablib.fablib import FablibManager as fablib_manager
fablib = fablib_manager() 
fablib.show_config()
# Out:
# <style type="text/css">
# #T_4f224 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4f224 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4f224 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4f224_row0_col0, #T_4f224_row0_col1, #T_4f224_row1_col0, #T_4f224_row1_col1, #T_4f224_row2_col0, #T_4f224_row2_col1, #T_4f224_row3_col0, #T_4f224_row3_col1, #T_4f224_row4_col0, #T_4f224_row4_col1, #T_4f224_row5_col0, #T_4f224_row5_col1, #T_4f224_row6_col0, #T_4f224_row6_col1, #T_4f224_row7_col0, #T_4f224_row7_col1, #T_4f224_row8_col0, #T_4f224_row8_col1, #T_4f224_row9_col0, #T_4f224_row9_col1, #T_4f224_row10_col0, #T_4f224_row10_col1, #T_4f224_row11_col0, #T_4f224_row11_col1, #T_4f224_row12_col0, #T_4f224_row12_col1, #T_4f224_row13_col0, #T_4f224_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4f224">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f224_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_4f224_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_4f224_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_4f224_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_4f224_row3_col1" class="data row3 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_4f224_row4_col1" class="data row4 col1" >vinita_p_0000073925</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_4f224_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_4f224_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_4f224_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_4f224_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_4f224_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_4f224_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_4f224_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_4f224_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_4f224_row13_col1" class="data row13 col1" >1.5.3</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_4f224 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_4f224 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_4f224 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_4f224_row0_col0, #T_4f224_row0_col1, #T_4f224_row1_col0, #T_4f224_row1_col1, #T_4f224_row2_col0, #T_4f224_row2_col1, #T_4f224_row3_col0, #T_4f224_row3_col1, #T_4f224_row4_col0, #T_4f224_row4_col1, #T_4f224_row5_col0, #T_4f224_row5_col1, #T_4f224_row6_col0, #T_4f224_row6_col1, #T_4f224_row7_col0, #T_4f224_row7_col1, #T_4f224_row8_col0, #T_4f224_row8_col1, #T_4f224_row9_col0, #T_4f224_row9_col1, #T_4f224_row10_col0, #T_4f224_row10_col1, #T_4f224_row11_col0, #T_4f224_row11_col1, #T_4f224_row12_col0, #T_4f224_row12_col1, #T_4f224_row13_col0, #T_4f224_row13_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_4f224">
#   <caption>FABlib Config</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_4f224_row0_col0" class="data row0 col0" >Credential Manager</td>
#       <td id="T_4f224_row0_col1" class="data row0 col1" >cm.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row1_col0" class="data row1 col0" >Orchestrator</td>
#       <td id="T_4f224_row1_col1" class="data row1 col1" >orchestrator.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row2_col0" class="data row2 col0" >Token File</td>
#       <td id="T_4f224_row2_col1" class="data row2 col1" >/home/fabric/.tokens.json</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row3_col0" class="data row3 col0" >Project ID</td>
#       <td id="T_4f224_row3_col1" class="data row3 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row4_col0" class="data row4 col0" >Bastion Username</td>
#       <td id="T_4f224_row4_col1" class="data row4 col1" >vinita_p_0000073925</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row5_col0" class="data row5 col0" >Bastion Private Key File</td>
#       <td id="T_4f224_row5_col1" class="data row5 col1" >/home/fabric/work/fabric_config/fabric_bastion_key</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row6_col0" class="data row6 col0" >Bastion Host</td>
#       <td id="T_4f224_row6_col1" class="data row6 col1" >bastion.fabric-testbed.net</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row7_col0" class="data row7 col0" >Bastion Private Key Passphrase</td>
#       <td id="T_4f224_row7_col1" class="data row7 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row8_col0" class="data row8 col0" >Slice Public Key File</td>
#       <td id="T_4f224_row8_col1" class="data row8 col1" >/home/fabric/work/fabric_config/slice_key.pub</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row9_col0" class="data row9 col0" >Slice Private Key File</td>
#       <td id="T_4f224_row9_col1" class="data row9 col1" >/home/fabric/work/fabric_config/slice_key</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row10_col0" class="data row10 col0" >Slice Private Key Passphrase</td>
#       <td id="T_4f224_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row11_col0" class="data row11 col0" >Log File</td>
#       <td id="T_4f224_row11_col1" class="data row11 col1" >/home/fabric/fablib.log</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row12_col0" class="data row12 col0" >Log Level</td>
#       <td id="T_4f224_row12_col1" class="data row12 col1" >INFO</td>
#     </tr>
#     <tr>
#       <td id="T_4f224_row13_col0" class="data row13 col0" >Version</td>
#       <td id="T_4f224_row13_col1" class="data row13 col1" >1.5.3</td>
#     </tr>
#   </tbody>
# </table>

# %%
# !chmod 600 {fablib.get_bastion_key_filename()}
# !chmod 600 {fablib.get_default_slice_private_key_file()}

# %% [markdown]
# ## Create and submit a slice

# %%
n_endpoints = 10
slice_name="bottleneck-" + str(n_endpoints) + '-test-1'
#slice = fablib.new_slice(name=slice_name)

# %% [markdown]
# This cell will try to identify a site that has sufficient resources for your experiment. But, you should still check in the [FABRIC Portal](https://portal.fabric-testbed.net/resources/all) to make sure it is not in maintenance or out of service - if so, you should run the cell again until you get a site that is ready to use.

# %%
exp_requires = {'core': 2*n_endpoints*4+32, 'nic': 2*n_endpoints*1, 'connectx5': 1}
while True:
    site_name = fablib.get_random_site()
    if ( (fablib.resources.get_core_available(site_name) > 1.2*exp_requires['core']) and
        (fablib.resources.get_component_available(site_name, 'SharedNIC-ConnectX-6') > 1.2**exp_requires['nic']) and
        (fablib.resources.get_component_available(site_name, 'SmartNIC-ConnectX-5') > 1.2*exp_requires['connectx5'])   ):
        break

fablib.show_site(site_name)
# Out:
# <style type="text/css">
# #T_89172 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_89172 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_89172 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_89172_row0_col0, #T_89172_row0_col1, #T_89172_row1_col0, #T_89172_row1_col1, #T_89172_row2_col0, #T_89172_row2_col1, #T_89172_row3_col0, #T_89172_row3_col1, #T_89172_row4_col0, #T_89172_row4_col1, #T_89172_row5_col0, #T_89172_row5_col1, #T_89172_row6_col0, #T_89172_row6_col1, #T_89172_row7_col0, #T_89172_row7_col1, #T_89172_row8_col0, #T_89172_row8_col1, #T_89172_row9_col0, #T_89172_row9_col1, #T_89172_row10_col0, #T_89172_row10_col1, #T_89172_row11_col0, #T_89172_row11_col1, #T_89172_row12_col0, #T_89172_row12_col1, #T_89172_row13_col0, #T_89172_row13_col1, #T_89172_row14_col0, #T_89172_row14_col1, #T_89172_row15_col0, #T_89172_row15_col1, #T_89172_row16_col0, #T_89172_row16_col1, #T_89172_row17_col0, #T_89172_row17_col1, #T_89172_row18_col0, #T_89172_row18_col1, #T_89172_row19_col0, #T_89172_row19_col1, #T_89172_row20_col0, #T_89172_row20_col1, #T_89172_row21_col0, #T_89172_row21_col1, #T_89172_row22_col0, #T_89172_row22_col1, #T_89172_row23_col0, #T_89172_row23_col1, #T_89172_row24_col0, #T_89172_row24_col1, #T_89172_row25_col0, #T_89172_row25_col1, #T_89172_row26_col0, #T_89172_row26_col1, #T_89172_row27_col0, #T_89172_row27_col1, #T_89172_row28_col0, #T_89172_row28_col1, #T_89172_row29_col0, #T_89172_row29_col1, #T_89172_row30_col0, #T_89172_row30_col1, #T_89172_row31_col0, #T_89172_row31_col1, #T_89172_row32_col0, #T_89172_row32_col1, #T_89172_row33_col0, #T_89172_row33_col1, #T_89172_row34_col0, #T_89172_row34_col1, #T_89172_row35_col0, #T_89172_row35_col1, #T_89172_row36_col0, #T_89172_row36_col1, #T_89172_row37_col0, #T_89172_row37_col1, #T_89172_row38_col0, #T_89172_row38_col1, #T_89172_row39_col0, #T_89172_row39_col1, #T_89172_row40_col0, #T_89172_row40_col1, #T_89172_row41_col0, #T_89172_row41_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_89172">
#   <caption>Site</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_89172_row0_col0" class="data row0 col0" >Name</td>
#       <td id="T_89172_row0_col1" class="data row0 col1" >DALL</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row1_col0" class="data row1 col0" >State</td>
#       <td id="T_89172_row1_col1" class="data row1 col1" >Active</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row2_col0" class="data row2 col0" >Address</td>
#       <td id="T_89172_row2_col1" class="data row2 col1" >1950 N Stemmons Fwy,Dallas TX 75207</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row3_col0" class="data row3 col0" >Location</td>
#       <td id="T_89172_row3_col1" class="data row3 col1" >(32.79908160563668, -96.82069027727609)</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row4_col0" class="data row4 col0" >Hosts</td>
#       <td id="T_89172_row4_col1" class="data row4 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row5_col0" class="data row5 col0" >CPUs</td>
#       <td id="T_89172_row5_col1" class="data row5 col1" >6</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row6_col0" class="data row6 col0" >Cores Available</td>
#       <td id="T_89172_row6_col1" class="data row6 col1" >290</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row7_col0" class="data row7 col0" >Cores Capacity</td>
#       <td id="T_89172_row7_col1" class="data row7 col1" >384</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row8_col0" class="data row8 col0" >Cores Allocated</td>
#       <td id="T_89172_row8_col1" class="data row8 col1" >94</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row9_col0" class="data row9 col0" >RAM Available</td>
#       <td id="T_89172_row9_col1" class="data row9 col1" >1306</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row10_col0" class="data row10 col0" >RAM Capacity</td>
#       <td id="T_89172_row10_col1" class="data row10 col1" >1506</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row11_col0" class="data row11 col0" >RAM Allocated</td>
#       <td id="T_89172_row11_col1" class="data row11 col1" >200</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row12_col0" class="data row12 col0" >Disk Available</td>
#       <td id="T_89172_row12_col1" class="data row12 col1" >63531</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row13_col0" class="data row13 col0" >Disk Capacity</td>
#       <td id="T_89172_row13_col1" class="data row13 col1" >64161</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row14_col0" class="data row14 col0" >Disk Allocated</td>
#       <td id="T_89172_row14_col1" class="data row14 col1" >630</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row15_col0" class="data row15 col0" >Basic NIC Available</td>
#       <td id="T_89172_row15_col1" class="data row15 col1" >365</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row16_col0" class="data row16 col0" >Basic NIC Capacity</td>
#       <td id="T_89172_row16_col1" class="data row16 col1" >381</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row17_col0" class="data row17 col0" >Basic NIC Allocated</td>
#       <td id="T_89172_row17_col1" class="data row17 col1" >16</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row18_col0" class="data row18 col0" >ConnectX-6 Available</td>
#       <td id="T_89172_row18_col1" class="data row18 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row19_col0" class="data row19 col0" >ConnectX-6 Capacity</td>
#       <td id="T_89172_row19_col1" class="data row19 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row20_col0" class="data row20 col0" >ConnectX-6 Allocated</td>
#       <td id="T_89172_row20_col1" class="data row20 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row21_col0" class="data row21 col0" >ConnectX-5 Available</td>
#       <td id="T_89172_row21_col1" class="data row21 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row22_col0" class="data row22 col0" >ConnectX-5 Capacity</td>
#       <td id="T_89172_row22_col1" class="data row22 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row23_col0" class="data row23 col0" >ConnectX-5 Allocated</td>
#       <td id="T_89172_row23_col1" class="data row23 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row24_col0" class="data row24 col0" >NVMe Available</td>
#       <td id="T_89172_row24_col1" class="data row24 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row25_col0" class="data row25 col0" >NVMe Capacity</td>
#       <td id="T_89172_row25_col1" class="data row25 col1" >10</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row26_col0" class="data row26 col0" >NVMe Allocated</td>
#       <td id="T_89172_row26_col1" class="data row26 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row27_col0" class="data row27 col0" >Tesla T4 Available</td>
#       <td id="T_89172_row27_col1" class="data row27 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row28_col0" class="data row28 col0" >Tesla T4 Capacity</td>
#       <td id="T_89172_row28_col1" class="data row28 col1" >2</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row29_col0" class="data row29 col0" >Tesla T4 Allocated</td>
#       <td id="T_89172_row29_col1" class="data row29 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row30_col0" class="data row30 col0" >RTX6000 Available</td>
#       <td id="T_89172_row30_col1" class="data row30 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row31_col0" class="data row31 col0" >RTX6000 Capacity</td>
#       <td id="T_89172_row31_col1" class="data row31 col1" >3</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row32_col0" class="data row32 col0" >RTX6000 Allocated</td>
#       <td id="T_89172_row32_col1" class="data row32 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row33_col0" class="data row33 col0" >A30 Available</td>
#       <td id="T_89172_row33_col1" class="data row33 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row34_col0" class="data row34 col0" >A30 Capacity</td>
#       <td id="T_89172_row34_col1" class="data row34 col1" >0</td>
#     </tr>
#     <tr>
#       <td id="T_89172_row35
# '<pandas.io.formats.style.Styler object at 0x7f9996347b80>'

# %%
# this cell sets up the hosts
slice.add_node(name='router', site=site_name, cores=32, ram=256, disk=25, image='default_ubuntu_22')

sender_names = ["sender-"+str(i) for i in range(n_endpoints)]
for n in sender_names:
    slice.add_node(name=n, site=site_name, cores=4, ram=32, disk=25, image='default_ubuntu_18')
    
receive_names = ["receiver-"+str(i) for i in range(n_endpoints)]
for n in receive_names:
    slice.add_node(name=n, site=site_name, cores=4, ram=32, disk=25, image='default_ubuntu_18')

# %%
# this cell sets up the network links
nets = [
    {"name": "link-sender",    "nodes": sender_names,  "idx": 0},
    {"name": "link-receiver",  "nodes": receive_names, "idx": 1}
]

router_iface = slice.get_node('router').add_component(model="NIC_ConnectX_5", name='link').get_interfaces()

for n in nets:
    ifaces = [slice.get_node(node).add_component(model="NIC_Basic", name=n["name"]).get_interfaces()[0] for node in n['nodes'] ] + [router_iface[n["idx"]]]
    slice.add_l2network(name=n["name"], type='L2Bridge', interfaces=ifaces)

# %% [markdown]
# When everything is ready, submit the slice and wait for it to get to "StableOK" state.  You can also see the state of your slice on the browser-based interface at https://portal.fabric-testbed.net/experiments#slices.
#
# In case of an error, you can modify the slice name in the first cell of the "Create and submit a slice" section, to try again with a new slice (different name). Then, return to this cell and click Run > Run All Above Selected Cell. Finally, re-run the `slice.submit()` cell.

# %%
slice.submit()
# Out:
# Retry: 20, Time: 5004 sec
# <style type="text/css">
# #T_bac95 tr:nth-child(even) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_bac95 tr:nth-child(odd) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_bac95 caption {
#   text-align: center;
#   font-size: 150%;
# }
# #T_bac95_row0_col0, #T_bac95_row0_col1, #T_bac95_row1_col0, #T_bac95_row1_col1, #T_bac95_row2_col0, #T_bac95_row2_col1, #T_bac95_row3_col0, #T_bac95_row3_col1, #T_bac95_row4_col0, #T_bac95_row4_col1, #T_bac95_row5_col0 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# #T_bac95_row5_col1 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# </style>
# <table id="T_bac95">
#   <caption>Slice</caption>
#   <thead>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_bac95_row0_col0" class="data row0 col0" >ID</td>
#       <td id="T_bac95_row0_col1" class="data row0 col1" >6011009b-bb9e-41ac-bdd0-44c99bc8b9ea</td>
#     </tr>
#     <tr>
#       <td id="T_bac95_row1_col0" class="data row1 col0" >Name</td>
#       <td id="T_bac95_row1_col1" class="data row1 col1" >bottleneck-10-test-1</td>
#     </tr>
#     <tr>
#       <td id="T_bac95_row2_col0" class="data row2 col0" >Lease Expiration (UTC)</td>
#       <td id="T_bac95_row2_col1" class="data row2 col1" >2023-08-20 05:29:28 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_bac95_row3_col0" class="data row3 col0" >Lease Start (UTC)</td>
#       <td id="T_bac95_row3_col1" class="data row3 col1" >2023-08-19 05:29:29 +0000</td>
#     </tr>
#     <tr>
#       <td id="T_bac95_row4_col0" class="data row4 col0" >Project ID</td>
#       <td id="T_bac95_row4_col1" class="data row4 col1" >073ee843-2310-45bd-a01f-a15d808827dc</td>
#     </tr>
#     <tr>
#       <td id="T_bac95_row5_col0" class="data row5 col0" >State</td>
#       <td id="T_bac95_row5_col1" class="data row5 col1" >StableOK</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_88971 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_88971 th {
#   text-align: left;
# }
# #T_88971 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_88971 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_88971 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T
col6 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# #T_014ea_row0_col7, #T_014ea_row1_col7 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: #c3ffc4;
# }
# #T_014ea_row0_col8, #T_014ea_row1_col8 {
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
#   background-color: ;
# }
# </style>
# <table id="T_014ea">
#   <caption>Networks</caption>
#   <thead>
#     <tr>
#       <th id="T_014ea_level0_col0" class="col_heading level0 col0" >ID</th>
#       <th id="T_014ea_level0_col1" class="col_heading level0 col1" >Name</th>
#       <th id="T_014ea_level0_col2" class="col_heading level0 col2" >Layer</th>
#       <th id="T_014ea_level0_col3" class="col_heading level0 col3" >Type</th>
#       <th id="T_014ea_level0_col4" class="col_heading level0 col4" >Site</th>
#       <th id="T_014ea_level0_col5" class="col_heading level0 col5" >Subnet</th>
#       <th id="T_014ea_level0_col6" class="col_heading level0 col6" >Gateway</th>
#       <th id="T_014ea_level0_col7" class="col_heading level0 col7" >State</th>
#       <th id="T_014ea_level0_col8" class="col_heading level0 col8" >Error</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_014ea_row0_col0" class="data row0 col0" >af64403c-6b68-4e36-819c-c750de56a1ed</td>
#       <td id="T_014ea_row0_col1" class="data row0 col1" >link-receiver</td>
#       <td id="T_014ea_row0_col2" class="data row0 col2" >L2</td>
#       <td id="T_014ea_row0_col3" class="data row0 col3" >L2Bridge</td>
#       <td id="T_014ea_row0_col4" class="data row0 col4" >DALL</td>
#       <td id="T_014ea_row0_col5" class="data row0 col5" >None</td>
#       <td id="T_014ea_row0_col6" class="data row0 col6" >None</td>
#       <td id="T_014ea_row0_col7" class="data row0 col7" >Active</td>
#       <td id="T_014ea_row0_col8" class="data row0 col8" ></td>
#     </tr>
#     <tr>
#       <td id="T_014ea_row1_col0" class="data row1 col0" >2bebbdea-7086-4eb5-97b6-42d0eb30acd1</td>
#       <td id="T_014ea_row1_col1" class="data row1 col1" >link-sender</td>
#       <td id="T_014ea_row1_col2" class="data row1 col2" >L2</td>
#       <td id="T_014ea_row1_col3" class="data row1 col3" >L2Bridge</td>
#       <td id="T_014ea_row1_col4" class="data row1 col4" >DALL</td>
#       <td id="T_014ea_row1_col5" class="data row1 col5" >None</td>
#       <td id="T_014ea_row1_col6" class="data row1 col6" >None</td>
#       <td id="T_014ea_row1_col7" class="data row1 col7" >Active</td>
#       <td id="T_014ea_row1_col8" class="data row1 col8" ></td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_01c27 caption {
#   text-align: center;
#   font-size: 150%;
#   caption-side: top;
# }
# #T_01c27 th {
#   text-align: left;
# }
# #T_01c27 tr:nth-child(even) {
#   background: #ffffff;
#   color: #231f20;
# }
# #T_01c27 tr:nth-child(odd) {
#   background: #dbf3ff;
#   color: #231f20;
# }
# #T_01c27 .level0 {
#   border: 1px black solid !important;
#   background: #ffffff;
#   color: #231f20;
# }
# #T_01c27_row0_col0, #T_01c27_row0_col1, #T_01c27_row0_col2, #T_01c27_row0_col3, #T_01c27_row0_col4, #T_01c27_row0_col5, #T_01c27_row0_col6, #T_01c27_row0_col7, #T_01c27_row0_col8, #T_01c27_row0_col9, #T_01c27_row0_col10, #T_01c27_row0_col11, #T_01c27_row1_col0, #T_01c27_row1_col1, #T_01c27_row1_col2, #T_01c27_row1_col3, #T_01c27_row1_col4, #T_01c27_row1_col5, #T_01c27_row1_col6, #T_01c27_row1_col7, #T_01c27_row1_col8, #T_01c27_row1_col9, #T_01c27_row1_col10, #T_01c27_row1_col11, #T_01c27_row2_col0, #T_01c27_row2_col1, #T_01c27_row2_col2, #T_01c27_row2_col3, #T_01c27_row2_col4, #T_01c27_row2_col5, #T_01c27_row2_col6, #T_01c27_row2_col7, #T_01c27_row2_col8, #T_01c27_row2_col9, #T_01c27_row2_col10, #T_01c27_row2_col11, #T_01c27_row3_col0, #T_01c27_row3_col1, #T_01c27_row3_col2, #T_01c27_row3_col3, #T_01c27_row3_col4, #T_01c27_row3_col5, #T_01c27_row3_col6, #T_01c27_row3_col7, #T_01c27_row3_col8, #T_01c27_row3_col9, #T_01c27_row3_col10, #T_01c27_row3_col11, #T_01c27_row4_col0, #T_01c27_row4_col1, #T_01c27_row4_col2, #T_01c27_row4_col3, #T_01c27_row4_col4, #T_01c27_row4_col5, #T_01c
27_row14_col1, #T_01c27_row14_col2, #T_01c27_row14_col3, #T_01c27_row14_col4, #T_01c27_row14_col5, #T_01c27_row14_col6, #T_01c27_row14_col7, #T_01c27_row14_col8, #T_01c27_row14_col9, #T_01c27_row14_col10, #T_01c27_row14_col11, #T_01c27_row15_col0, #T_01c27_row15_col1, #T_01c27_row15_col2, #T_01c27_row15_col3, #T_01c27_row15_col4, #T_01c27_row15_col5, #T_01c27_row15_col6, #T_01c27_row15_col7, #T_01c27_row15_col8, #T_01c27_row15_col9, #T_01c27_row15_col10, #T_01c27_row15_col11, #T_01c27_row16_col0, #T_01c27_row16_col1, #T_01c27_row16 ...
#   text-align: left;
#   border: 1px #231f20 solid !important;
#   overwrite: False;
# }
# </style>
# <table id="T_01c27">
#   <caption>Interfaces</caption>
#   <thead>
#     <tr>
#       <th id="T_01c27_level0_col0" class="col_heading level0 col0" >Name</th>
#       <th id="T_01c27_level0_col1" class="col_heading level0 col1" >Short Name</th>
#       <th id="T_01c27_level0_col2" class="col_heading level0 col2" >Node</th>
#       <th id="T_01c27_level0_col3" class="col_heading level0 col3" >Network</th>
#       <th id="T_01c27_level0_col4" class="col_heading level0 col4" >Bandwidth</th>
#       <th id="T_01c27_level0_col5" class="col_heading level0 col5" >Mode</th>
#       <th id="T_01c27_level0_col6" class="col_heading level0 col6" >VLAN</th>
#       <th id="T_01c27_level0_col7" class="col_heading level0 col7" >MAC</th>
#       <th id="T_01c27_level0_col8" class="col_heading level0 col8" >Physical Device</th>
#       <th id="T_01c27_level0_col9" class="col_heading level0 col9" >Device</th>
#       <th id="T_01c27_level0_col10" class="col_heading level0 col10" >IP Address</th>
#       <th id="T_01c27_level0_col11" class="col_heading level0 col11" >Numa Node</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_01c27_row0_col0" class="data row0 col0" >router-link-p1</td>
#       <td id="T_01c27_row0_col1" class="data row0 col1" >p1</td>
#       <td id="T_01c27_row0_col2" class="data row0 col2" >router</td>
#       <td id="T_01c27_row0_col3" class="data row0 col3" >link-sender</td>
#       <td id="T_01c27_row0_col4" class="data row0 col4" >25</td>
#       <td id="T_01c27_row0_col5" class="data row0 col5" >config</td>
#       <td id="T_01c27_row0_col6" class="data row0 col6" ></td>
#       <td id="T_01c27_row0_col7" class="data row0 col7" >B8:CE:F6:AF:85:56</td>
#       <td id="T_01c27_row0_col8" class="data row0 col8" >ens7np0</td>
#       <td id="T_01c27_row0_col9" class="data row0 col9" >ens7np0</td>
#       <td id="T_01c27_row0_col10" class="data row0 col10" >None</td>
#       <td id="T_01c27_row0_col11" class="data row0 col11" >6</td>
#     </tr>
#     <tr>
#       <td id="T_01c27_row1_col0" class="data row1 col0" >router-link-p2</td>
#       <td id="T_01c27_row1_col
# Time to print interfaces 5129 seconds
# '6011009b-bb9e-41ac-bdd0-44c99bc8b9ea'

# %% [markdown]
# ## Configure resources

# %%
slice.get_state()
# Out:
# 'StableOK'

# %%
slice = fablib.get_slice(name=slice_name)

# %%
slice.wait_ssh(progress=True)
# Out:
# Waiting for slice . Slice state: StableOK
# Waiting for ssh in slice ........................................................ Timeout exceeded (1800 sec). Slice: bottleneck-10-test-1 (StableOK)
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 slice.wait_ssh(progress=True)
#
# File /opt/conda/lib/python3.10/site-packages/fabrictestbed_extensions/fablib/slice.py:1586, in Slice.wait_ssh(self, timeout, interval, progress)
#    1584 except Exception as e:
#    1585     if not time.time() < timeout_start + timeout:
# -> 1586         raise e
#    1587     logging.warning(f"wait ssh retrying: {e}")
#    1589 time.sleep(interval)
#
# File /opt/conda/lib/python3.10/site-packages/fabrictestbed_extensions/fablib/slice.py:1581, in Slice.wait_ssh(self, timeout, interval, progress)
#    1577         if progress:
#    1578             print(
#    1579                 f" Timeout exceeded ({timeout} sec). Slice: {slice.name} ({slice.state})"
#    1580             )
# -> 1581         raise Exception(
#    1582             f" Timeout exceeded ({timeout} sec). Slice: {slice.name} ({slice.state})"
#    1583         )
#    1584 except Exception as e:
#    1585     if not time.time() < timeout_start + timeout:
#
# Exception:  Timeout exceeded (1800 sec). Slice: bottleneck-10-test-1 (StableOK)

# %% [markdown]
# Bring up all of the network interfaces:

# %%
for iface in slice.get_interfaces():
    iface.ip_link_up()

# %% [markdown]
# Assign addresses to router interfaces and enable forwarding:

# %%
from ipaddress import ip_address, IPv4Address, IPv4Network

if_sender = slice.get_interface('router-link-p1')
if_sender.ip_addr_add(addr="10.10.1.1", subnet=IPv4Network("10.10.1.0/24"))
if_receive = slice.get_interface('router-link-p2')
if_receive.ip_addr_add(addr="10.10.2.1", subnet=IPv4Network("10.10.2.0/24"))

slice.get_node(name='router').execute("sudo sysctl -w net.ipv4.ip_forward=1")

# %% [markdown]
# Assign addresses to host (sender and receiver) interfaces and set up routes:

# %%
for i in range(n_endpoints):
    if_name = slice.get_interface('sender-' + str(i) + '-link-sender-p1')
    if_name.ip_addr_add(addr="10.10.1.1" + str(i) , subnet=IPv4Network("10.10.1.0/24"))
    slice.get_node(name='sender-' + str(i)).ip_route_add(subnet=IPv4Network("10.10.2.0/24"), gateway="10.10.1.1")
    
for i in range(n_endpoints):
    if_name = slice.get_interface('receiver-' + str(i) + '-link-receiver-p1')
    if_name.ip_addr_add(addr="10.10.2.1" + str(i) , subnet=IPv4Network("10.10.2.0/24"))
    slice.get_node(name='receiver-' + str(i)).ip_route_add(subnet=IPv4Network("10.10.1.0/24"), gateway="10.10.2.1")

# %% [markdown]
# Also install `iperf3` on sender and receiver hosts:

# %%
sender_nodes = [slice.get_node(name='sender-' + str(i))  for i in range(n_endpoints)]
receiver_nodes = [slice.get_node(name='receiver-' + str(i))  for i in range(n_endpoints)]

# %%
from ipaddress import ip_address, IPv6Address
for n in sender_nodes:
    if type(ip_address(n.get_management_ip())) is IPv6Address:
        n.upload_file('nat64.sh', 'nat64.sh')
        stdout, stderr = n.execute(f'chmod +x nat64.sh && ./nat64.sh')
    n.execute("sudo apt-get update; sudo apt-get -y install build-essential ")
    n.execute_thread("sudo modprobe tcp_bbr")
    n.execute_thread("sudo git clone https://github.com/vinitaparasrampuria/iperf.git /iperf; sudo chmod +x /iperf/configure; sudo bash /iperf/configure;\
                     sudo make; sudo make check; sudo make install; sudo ldconfig")
              
for n in receiver_nodes:
    n.execute_thread("sudo apt update; sudo apt -y install iperf3;  sudo modprobe tcp_bbr")

# %%
for n in sender_nodes:
    n.execute("sudo apt-get update; sudo apt-get install -y python3-pip ethtool netcat moreutils ",quiet=True)
    n.execute("sudo python3 -m pip install scikit-learn numpy pandas matplotlib seaborn", quiet=True)

# %%
for n in sender_nodes:
    n.execute("iperf3 -version")

# %%
from datetime import datetime
from datetime import timezone
from datetime import timedelta

# Set end date to 4 days from now
end_date = (datetime.now(timezone.utc) + timedelta(days=4)).strftime("%Y-%m-%d %H:%M:%S %z")
slice.renew(end_date)
